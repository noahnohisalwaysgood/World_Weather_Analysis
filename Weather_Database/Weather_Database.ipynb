# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
print (coordinates)
# Out:
# [(80.11615502790781, -49.656361922415044), (-33.93373515008739, -126.94620251826231), (80.57318070951641, 51.5647810997356), (54.7651768801511, 98.33345292137267), (64.80116537916086, -21.727147901946807), (54.73809904567909, -56.1629547680279), (-33.36700201986888, -45.25702019218602), (73.05779239630454, -105.86078903357846), (-38.382982931547865, -4.924488630767939), (-34.26825458733479, 42.827104646534224), (-27.874232140874078, 171.90352999113964), (43.444123969373834, 170.4884824351842), (-57.74227190099534, -124.81250509446346), (-4.799967202746913, -135.3116202426816), (-73.31622714452774, -48.59693453020097), (-20.57562795874422, 166.16287893775603), (57.01755791479738, 108.67447811927758), (47.835370563120506, 171.8044782876612), (52.57625561718018, -85.62281866198494), (87.42358037155955, 131.49131527920798), (73.75142989893172, 30.466481137367566), (-11.916392528714582, 32.89466171810423), (-30.492304067747384, 172.31702821341997), (20.05722332138444, -52.461981840594945), (-45.84944249363388, 86.74729036719594), (-9.081691551106033, 165.0996125251529), (-15.40819204768637, 80.86068984997223), (80.63990333298725, 6.989260387035358), (87.31803227789896, 32.94424871492234), (-29.00775296864456, -90.42938022213343), (19.044734951601043, -20.703463935589724), (-43.346741467732045, -97.70828917620427), (-1.148232889992073, -84.78661291194206), (-32.10106664250303, 76.10478701339804), (19.891206021030754, -13.484548628225866), (7.020387888789713, -101.21753080986484), (12.591221207124704, 76.78892871006275), (16.41456520270488, -92.75391919366012), (75.432538756583, 19.34753838295535), (22.362648186221676, -130.4353924079549), (-9.035958753593874, 35.70203707149324), (-4.634078299245033, -167.58893089199634), (69.15579767450751, -52.0381760846532), (23.070628523426976, -72.23448349522666), (-70.11798089534349, 73.2189933324621), (83.47093389521348, 92.59804022064634), (45.279838442005115, -77.84826724225361), (22.838464077543847, 169.40978577455434), (-43.09053245073142, -131.15637045174205), (12.902513331662163, 92.86159493892444), (50.4661931854304, 122.69672742506339), (-1.6570712206678735, -66.2537637452485), (-53.996063161009644, -153.97308569760648), (32.8017554211322, 163.65433375893218), (-59.490294929936255, -92.776699780733), (-77.86519724902206, -108.71558489290936), (-39.64182653485812, 141.72616496775657), (-63.85968788915461, -119.43463666761298), (16.078212359738743, 130.43118355964043), (52.226240276276855, 151.9818800041644), (79.52563240199882, 173.83104456674647), (84.01658463193021, 157.8573883293783), (7.077029998780958, 136.9711983890303), (43.254346527085374, -173.92204433969815), (30.02753243152216, -32.193767808894705), (79.21097725428751, 104.16668640238771), (-66.24101843914869, -83.74405478465887), (-89.97313236657156, 8.144022036970767), (82.0959714667743, 29.342540530989112), (-65.3749146742922, 95.52062043116001), (71.46793883077308, -77.57737278731113), (2.642916847051268, 109.13674339698952), (11.350371136281083, -44.792001356591356), (-0.91997972974589, 47.157677538140945), (83.53657145495876, -140.9478792864355), (-12.961318744526395, -90.16306461279095), (-72.93317713874646, 161.5455783011617), (-44.00573403584986, 112.31417909905917), (17.21371139903519, -172.06760540057797), (-10.063717638165613, 144.54216301345923), (53.5207001439592, 145.5559240052989), (-48.6517415729114, 75.64565671675507), (66.14305349444373, 89.0966056008811), (-1.5130050374231985, -101.7767680536331), (14.51293818227316, -53.32802534785938), (-56.1837157080267, -88.09033880911173), (-81.31087108947516, 163.26758239293866), (22.05790131370665, -61.12205072554458), (13.998446477882268, -72.96959999502492), (68.20581521569798, 107.94527282087768), (-40.012915727837935, -83.90334240080438), (2.6374858737114266, -95.94979988234708), (58.00431284436115, -112.2694929197692), (-35.407197394206705, -151.48729124265122), (-45.461160692951324, -108.80880042719903), (-23.546120177711202, -50.742458136867725), (-27.9026100 ...

# %%
from citipy import citipy

# %%
# Get the nearest city using the citipy module
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 760

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Perform an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
import json

# %%
# Retrieve the following information from the API call:
# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | upernavik
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 1 | uk
# City not found. Skipping...
# Processing Record 5 of Set 1 | borgarnes
# Processing Record 6 of Set 1 | saint anthony
# Processing Record 7 of Set 1 | cidreira
# Processing Record 8 of Set 1 | yellowknife
# Processing Record 9 of Set 1 | jamestown
# Processing Record 10 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 1 | vao
# Processing Record 12 of Set 1 | nikolskoye
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | fayaoue
# Processing Record 16 of Set 1 | alekseyevsk
# Processing Record 17 of Set 1 | longlac
# City not found. Skipping...
# Processing Record 18 of Set 1 | tiksi
# Processing Record 19 of Set 1 | berlevag
# Processing Record 20 of Set 1 | lundazi
# Processing Record 21 of Set 1 | ahipara
# Processing Record 22 of Set 1 | saint-francois
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | lata
# Processing Record 25 of Set 1 | hithadhoo
# Processing Record 26 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 1 | lebu
# Processing Record 28 of Set 1 | santa maria
# Processing Record 29 of Set 1 | castro
# Processing Record 30 of Set 1 | salinas
# Processing Record 31 of Set 1 | bambous virieux
# Processing Record 32 of Set 1 | atar
# Processing Record 33 of Set 1 | puerto escondido
# Processing Record 34 of Set 1 | mandya
# Processing Record 35 of Set 1 | chiapilla
# Processing Record 36 of Set 1 | longyearbyen
# Processing Record 37 of Set 1 | lompoc
# Processing Record 38 of Set 1 | mlimba
# Processing Record 39 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 40 of Set 1 | qasigiannguit
# Processing Record 41 of Set 1 | cockburn harbour
# City not found. Skipping...
# Processing Record 42 of Set 1 | saint-philippe
# Processing Record 43 of Set 1 | talnakh
# Processing Record 44 of Set 1 | eganville
# Processing Record 45 of Set 1 | butaritari
# Processing Record 46 of Set 1 | port blair
# Processing Record 47 of Set 1 | alihe
# Processing Record 48 of Set 1 | maraa
# Processing Record 49 of Set 1 | mataura
# Processing Record 50 of Set 1 | severo-kurilsk
# Processing Record 1 of Set 2 | punta arenas
# Processing Record 2 of Set 2 | portland
# Processing Record 3 of Set 2 | alugan
# Processing Record 4 of Set 2 | oktyabrskiy
# Processing Record 5 of Set 2 | komsomolskiy
# Processing Record 6 of Set 2 | cherskiy
# Processing Record 7 of Set 2 | airai
# Processing Record 8 of Set 2 | provideniya
# Processing Record 9 of Set 2 | ribeira grande
# Processing Record 10 of Set 2 | khatanga
# Processing Record 11 of Set 2 | hermanus
# Processing Record 12 of Set 2 | mehamn
# Processing Record 13 of Set 2 | clyde river
# Processing Record 14 of Set 2 | pemangkat
# Processing Record 15 of Set 2 | cayenne
# Processing Record 16 of Set 2 | mogadishu
# Processing Record 17 of Set 2 | tuktoyaktuk
# Processing Record 18 of Set 2 | pimentel
# Processing Record 19 of Set 2 | bluff
# Processing Record 20 of Set 2 | albany
# Processing Record 21 of Set 2 | kapaa
# Processing Record 22 of Set 2 | daru
# Processing Record 23 of Set 2 | ekhabi
# Processing Record 24 of Set 2 | mahebourg
# Processing Record 25 of Set 2 | svetlogorsk
# Processing Record 26 of Set 2 | puerto ayora
# Processing Record 27 of Set 2 | bathsheba
# Processing Record 28 of Set 2 | the valley
# Processing Record 29 of Set 2 | manaure
# Processing Record 30 of Set 2 | aykhal
# Processing Record 31 of Set 2 | ancud
# Processing Record 32 of Set 2 | athabasca
# Processing Record 33 of Set 2 | assai
# Processing Record 34 of Set 2 | ilhabela
# Processing Record 35 of Set 2 | leningradskiy
# Processing Record 36 of Set 2 | tukrah
# Processing Record 37 of Set 2 | shimoda
# Processing Record 38 of Set 2 | dikson
# Processing Record 39 of Set 2 | mayya
# Processing Record 40 of Set 2 | amahai
# Processing Record 41 of Set 2 | sepuka
# Processing Record 42 of Set 2 | cabinda
# Processing Record 43 of Set 2 | slupsk
# Processing Record 44 of Set 2 | cockburn town
# Processing Record 45 of Set 2 | katsuura
# Processing Record 46 of Set 2 | koumac
# Processing Record 47 of Set 2 | newport
# Processing Record 48 of Set 2 | yaan
# Processing Record 49 of Set 2 | viedma
# Processing Record 50 of Set 2 | vostok
# Processing Record 1 of Set 3 | corrales
# Processing Record 2 of Set 3 | codrington
# Processing Record 3 of Set 3 | dudinka
# Processing Record 4 of Set 3 | galle
# Processing Record 5 of Set 3 | porto walter
# Processing Record 6 of Set 3 | seymchan
# Processing Record 7 of Set 3 | beringovskiy
# Processing Record 8 of Set 3 | kruisfontein
# Processing Record 9 of Set 3 | victoria
# Processing Record 10 of Set 3 | ponta do sol
# Processing Record 11 of Set 3 | bengkulu
# Processing Record 12 of Set 3 | arraial do cabo
# Processing Record 13 of Set 3 | vaini
# Processing Record 14 of Set 3 | slave lake
# Processing Record 15 of Set 3 | sioux lookout
# Processing Record 16 of Set 3 | havelock
# Processing Record 17 of Set 3 | topolobampo
# Processing Record 18 of Set 3 | mar del plata
# Processing Record 19 of Set 3 | srednekolymsk
# Processing Record 20 of Set 3 | macroom
# Processing Record 21 of Set 3 | khasan
# Processing Record 22 of Set 3 | half moon bay
# Processing Record 23 of Set 3 | vanimo
# Processing Record 24 of Set 3 | chuy
# Processing Record 25 of Set 3 | ostrovnoy
# Processing Record 26 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 3 | namatanai
# Processing Record 28 of Set 3 | lasa
# Processing Record 29 of Set 3 | harbour breton
# Processing Record 30 of Set 3 | miyako
# Processing Record 31 of Set 3 | khash
# Processing Record 32 of Set 3 | denpasar
# Processing Record 33 of Set 3 | dolbeau
# City not found. Skipping...
# Processing Record 34 of Set 3 | sobolevo
# Processing Record 35 of Set 3 | itaqui
# Processing Record 36 of Set 3 | bredasdorp
# Processing Record 37 of Set 3 | usinsk
# Processing Record 38 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 3 | vanino
# Processing Record 40 of Set 3 | fairbanks
# Processing Record 41 of Set 3 | jiazi
# Processing Record 42 of Set 3 | tasiilaq
# Processing Record 43 of Set 3 | mayumba
# Processing Record 44 of Set 3 | port alfred
# Processing Record 45 of Set 3 | pierre
# Processing Record 46 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 3 | avarua
# Processing Record 48 of Set 3 | koutiala
# Processing Record 49 of Set 3 | carnarvon
# Processing Record 50 of Set 3 | kodiak
# Processing Record 1 of Set 4 | fort saint john
# City not found. Skipping...
# Processing Record 2 of Set 4 | plettenberg bay
# Processing Record 3 of Set 4 | itaituba
# Processing Record 4 of Set 4 | la rioja
# Processing Record 5 of Set 4 | new norfolk
# Processing Record 6 of Set 4 | qaanaaq
# Processing Record 7 of Set 4 | roma
# Processing Record 8 of Set 4 | hamilton
# Processing Record 9 of Set 4 | norton shores
# Processing Record 10 of Set 4 | bela vista
# Processing Record 11 of Set 4 | gladstone
# Processing Record 12 of Set 4 | nha trang
# Processing Record 13 of Set 4 | vardo
# Processing Record 14 of Set 4 | yekaterinoslavka
# Processing Record 15 of Set 4 | tsabong
# Processing Record 16 of Set 4 | payyannur
# Processing Record 17 of Set 4 | thompson
# Processing Record 18 of Set 4 | road town
# Processing Record 19 of Set 4 | opuwo
# Processing Record 20 of Set 4 | chokurdakh
# Processing Record 21 of Set 4 | barra
# Processing Record 22 of Set 4 | zrnovci
# Processing Record 23 of Set 4 | husavik
# Processing Record 24 of Set 4 | la argentina
# Processing Record 25 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 26 of Set 4 | vylgort
# City not found. Skipping...
# Processing Record 27 of Set 4 | banda aceh
# Processing Record 28 of Set 4 | karratha
# Processing Record 29 of Set 4 | east london
# Processing Record 30 of Set 4 | shaunavon
# Processing Record 31 of Set 4 | la ronge
# Processing Record 32 of Set 4 | shirokiy
# Processing Record 33 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 4 | alofi
# Processing Record 35 of Set 4 | igmaya-an
# Processing Record 36 of Set 4 | natal
# Processing Record 37 of Set 4 | ust-koksa
# Processing Record 38 of Set 4 | iqaluit
# Processing Record 39 of Set 4 | baoqing
# Processing Record 40 of Set 4 | taltal
# Processing Record 41 of Set 4 | inhambane
# Processing Record 42 of Set 4 | moussoro
# Processing Record 43 of Set 4 | klaksvik
# Processing Record 44 of Set 4 | caledon
# Processing Record 45 of Set 4 | merauke
# Processing Record 46 of Set 4 | san patricio
# Processing Record 47 of Set 4 | hobart
# Processing Record 48 of Set 4 | hasaki
# Processing Record 49 of Set 4 | otradinskiy
# City not found. Skipping...
# Processing Record 50 of Set 4 | bodaybo
# Processing Record 1 of Set 5 | snellville
# Processing Record 2 of Set 5 | puri
# Processing Record 3 of Set 5 | kerki
# City not found. Skipping...
# Processing Record 4 of Set 5 | sibolga
# Processing Record 5 of Set 5 | murgab
# Processing Record 6 of Set 5 | katol
# Processing Record 7 of Set 5 | nome
# Processing Record 8 of Set 5 | turiacu
# Processing Record 9 of Set 5 | chernushka
# Processing Record 10 of Set 5 | abnub
# Processing Record 11 of Set 5 | sitka
# Processing Record 12 of Set 5 | taywarah
# Processing Record 13 of Set 5 | khandagayty
# Processing Record 14 of Set 5 | uryupinsk
# Processing Record 15 of Set 5 | cabo san lucas
# Processing Record 16 of Set 5 | znamenskoye
# Processing Record 17 of Set 5 | vila franca do campo
# Processing Record 18 of Set 5 | kaitangata
# Processing Record 19 of Set 5 | baoding
# Processing Record 20 of Set 5 | juneau
# Processing Record 21 of Set 5 | constitucion
# Processing Record 22 of Set 5 | san quintin
# Processing Record 23 of Set 5 | taunggyi
# Processing Record 24 of Set 5 | labuhan
# Processing Record 25 of Set 5 | pochutla
# Processing Record 26 of Set 5 | villa carlos paz
# Processing Record 27 of Set 5 | souillac
# Processing Record 28 of Set 5 | georgetown
# Processing Record 29 of Set 5 | saldanha
# Processing Record 30 of Set 5 | mount isa
# Processing Record 31 of Set 5 | alta floresta
# Processing Record 32 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 5 | college
# Processing Record 34 of Set 5 | namibe
# Processing Record 35 of Set 5 | manzhouli
# Processing Record 36 of Set 5 | umm lajj
# Processing Record 37 of Set 5 | kavaratti
# Processing Record 38 of Set 5 | sao joao do piaui
# Processing Record 39 of Set 5 | cape town
# Processing Record 40 of Set 5 | flinders
# Processing Record 41 of Set 5 | sorland
# Processing Record 42 of Set 5 | pirovskoye
# Processing Record 43 of Set 5 | adrar
# Processing Record 44 of Set 5 | bacuit
# City not found. Skipping...
# Processing Record 45 of Set 5 | punta alta
# Processing Record 46 of Set 5 | nanortalik
# Processing Record 47 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 5 | tura
# Processing Record 49 of Set 5 | jumla
# Processing Record 50 of Set 5 | san buenaventura
# Processing Record 1 of Set 6 | saint george
# Processing Record 2 of Set 6 | tecoanapa
# Processing Record 3 of Set 6 | brae
# Processing Record 4 of Set 6 | khipro
# Processing Record 5 of Set 6 | port hardy
# Processing Record 6 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 6 | guadix
# Processing Record 8 of Set 6 | barra dos coqueiros
# Processing Record 9 of Set 6 | makarov
# Processing Record 10 of Set 6 | aklavik
# Processing Record 11 of Set 6 | coihaique
# Processing Record 12 of Set 6 | narsaq
# Processing Record 13 of Set 6 | walvis bay
# Processing Record 14 of Set 6 | yining
# Processing Record 15 of Set 6 | sabang
# Processing Record 16 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 17 of Set 6 | whitehorse
# Processing Record 18 of Set 6 | antalaha
# Processing Record 19 of Set 6 | sao joao da barra
# Processing Record 20 of Set 6 | manokwari
# Processing Record 21 of Set 6 | derbent
# Processing Record 22 of Set 6 | kasongo
# Processing Record 23 of Set 6 | ilulissat
# Processing Record 24 of Set 6 | troitsk
# Processing Record 25 of Set 6 | guia de isora
# Processing Record 26 of Set 6 | usak
# Processing Record 27 of Set 6 | omboue
# Processing Record 28 of Set 6 | kuusamo
# Processing Record 29 of Set 6 | benjamin hill
# Processing Record 30 of Set 6 | ugra
# Processing Record 31 of Set 6 | gravdal
# Processing Record 32 of Set 6 | yenagoa
# Processing Record 33 of Set 6 | uvira
# Processing Record 34 of Set 6 | bethel
# Processing Record 35 of Set 6 | nalut
# Processing Record 36 of Set 6 | esperance
# Processing Record 37 of Set 6 | superior
# Processing Record 38 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 6 | aberdeen
# Processing Record 40 of Set 6 | kramat
# Processing Record 41 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 6 | buchanan
# Processing Record 43 of Set 6 | inderborskiy
# City not found. Skipping...
# Processing Record 44 of Set 6 | huarmey
# Processing Record 45 of Set 6 | bereznik
# Processing Record 46 of Set 6 | asau
# Processing Record 47 of Set 6 | faanui
# Processing Record 48 of Set 6 | irbil
# Processing Record 49 of Set 6 | kaeo
# Processing Record 50 of Set 6 | maputo
# Processing Record 1 of Set 7 | kavieng
# Processing Record 2 of Set 7 | barrow
# Processing Record 3 of Set 7 | nyurba
# Processing Record 4 of Set 7 | riyadh
# Processing Record 5 of Set 7 | chernyshevskiy
# Processing Record 6 of Set 7 | touros
# Processing Record 7 of Set 7 | pevek
# Processing Record 8 of Set 7 | nueva loja
# Processing Record 9 of Set 7 | acapulco
# Processing Record 10 of Set 7 | beira
# Processing Record 11 of Set 7 | creston
# Processing Record 12 of Set 7 | santa marta
# Processing Record 13 of Set 7 | shenjiamen
# Processing Record 14 of Set 7 | verkhnevilyuysk
# Processing Record 15 of Set 7 | izumo
# Processing Record 16 of Set 7 | khingansk
# Processing Record 17 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 7 | geraldton
# Processing Record 19 of Set 7 | homer
# Processing Record 20 of Set 7 | lazaro cardenas
# Processing Record 21 of Set 7 | ratangarh
# Processing Record 22 of Set 7 | de-kastri
# Processing Record 23 of Set 7 | bandarbeyla
# Processing Record 24 of Set 7 | pangnirtung
# Processing Record 25 of Set 7 | isla mujeres
# Processing Record 26 of Set 7 | kizner
# Processing Record 27 of Set 7 | dunedin
# Processing Record 28 of Set 7 | mahadday weyne
# City not found. Skipping...
# Processing Record 29 of Set 7 | salekhard
# Processing Record 30 of Set 7 | itanhaem
# Processing Record 31 of Set 7 | madinat sittah uktubar
# Processing Record 32 of Set 7 | tongren
# Processing Record 33 of Set 7 | hilo
# Processing Record 34 of Set 7 | broome
# Processing Record 35 of Set 7 | kholm
# Processing Record 36 of Set 7 | te anau
# Processing Record 37 of Set 7 | turka
# Processing Record 38 of Set 7 | carauari
# Processing Record 39 of Set 7 | luganville
# Processing Record 40 of Set 7 | pasighat
# Processing Record 41 of Set 7 | buraydah
# Processing Record 42 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 7 | xichang
# Processing Record 44 of Set 7 | yar-sale
# Processing Record 45 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 7 | yunjinghong
# City not found. Skipping...
# Processing Record 47 of Set 7 | hobyo
# Processing Record 48 of Set 7 | ambilobe
# Processing Record 49 of Set 7 | yatou
# Processing Record 50 of Set 7 | faya
# Processing Record 1 of Set 8 | port elizabeth
# Processing Record 2 of Set 8 | rio gallegos
# Processing Record 3 of Set 8 | hovd
# Processing Record 4 of Set 8 | kaoma
# Processing Record 5 of Set 8 | la crosse
# Processing Record 6 of Set 8 | ayr
# Processing Record 7 of Set 8 | sakakah
# Processing Record 8 of Set 8 | vondrozo
# Processing Record 9 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 8 | morgan city
# Processing Record 11 of Set 8 | ust-nera
# Processing Record 12 of Set 8 | kautokeino
# Processing Record 13 of Set 8 | junction city
# Processing Record 14 of Set 8 | lavrentiya
# Processing Record 15 of Set 8 | kupino
# Processing Record 16 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 8 | saskylakh
# Processing Record 18 of Set 8 | atlantic beach
# Processing Record 19 of Set 8 | boddam
# Processing Record 20 of Set 8 | sohbatpur
# Processing Record 21 of Set 8 | tarui
# Processing Record 22 of Set 8 | pedra azul
# Processing Record 23 of Set 8 | katangli
# Processing Record 24 of Set 8 | kamyaran
# Processing Record 25 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 8 | vilhena
# Processing Record 27 of Set 8 | fortuna
# Processing Record 28 of Set 8 | baghdad
# Processing Record 29 of Set 8 | nuuk
# Processing Record 30 of Set 8 | pawai
# Processing Record 31 of Set 8 | tucurui
# Processing Record 32 of Set 8 | kahului
# Processing Record 33 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 34 of Set 8 | porto novo
# Processing Record 35 of Set 8 | yumen
# Processing Record 36 of Set 8 | los llanos de aridane
# Processing Record 37 of Set 8 | lorengau
# Processing Record 38 of Set 8 | forestville
# Processing Record 39 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 40 of Set 8 | sabha
# Processing Record 41 of Set 8 | yarada
# Processing Record 42 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 43 of Set 8 | ustye
# Processing Record 44 of Set 8 | ixtapa
# Processing Record 45 of Set 8 | imbituba
# Processing Record 46 of Set 8 | arlit
# Processing Record 47 of Set 8 | anadyr
# Processing Record 48 of Set 8 | pisco
# Processing Record 49 of Set 8 | gat
# Processing Record 50 of Set 8 | cosenza
# Processing Record 1 of Set 9 | mahajanga
# Processing Record 2 of Set 9 | dawlatabad
# Processing Record 3 of Set 9 | labuan
# Processing Record 4 of Set 9 | lockhart
# Processing Record 5 of Set 9 | rawson
# Processing Record 6 of Set 9 | sibu
# Processing Record 7 of Set 9 | axim
# Processing Record 8 of Set 9 | santa ines
# Processing Record 9 of Set 9 | eydhafushi
# Processing Record 10 of Set 9 | puerto ayacucho
# Processing Record 11 of Set 9 | chippewa falls
# Processing Record 12 of Set 9 | chastoozerye
# City not found. Skipping...
# Processing Record 13 of Set 9 | launceston
# Processing Record 14 of Set 9 | bulawayo
# Processing Record 15 of Set 9 | hutchinson
# Processing Record 16 of Set 9 | kattivakkam
# Processing Record 17 of Set 9 | nouadhibou
# Processing Record 18 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 9 | sisimiut
# Processing Record 20 of Set 9 | isangel
# Processing Record 21 of Set 9 | roald
# Processing Record 22 of Set 9 | cabra
# Processing Record 23 of Set 9 | majene
# Processing Record 24 of Set 9 | goba
# Processing Record 25 of Set 9 | saint-joseph
# Processing Record 26 of Set 9 | quimper
# Processing Record 27 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 28 of Set 9 | grindavik
# Processing Record 29 of Set 9 | payo
# Processing Record 30 of Set 9 | arua
# Processing Record 31 of Set 9 | belmonte
# Processing Record 32 of Set 9 | grajau
# Processing Record 33 of Set 9 | hit
# Processing Record 34 of Set 9 | ardistan
# City not found. Skipping...
# Processing Record 35 of Set 9 | vitim
# Processing Record 36 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 9 | amga
# Processing Record 38 of Set 9 | arecibo
# Processing Record 39 of Set 9 | cortez
# Processing Record 40 of Set 9 | chimbote
# Processing Record 41 of Set 9 | dafeng
# Processing Record 42 of Set 9 | mandalgovi
# Processing Record 43 of Set 9 | yuzhnyy
# Processing Record 44 of Set 9 | sao filipe
# Processing Record 45 of Set 9 | palembang
# Processing Record 46 of Set 9 | vicam
# Processing Record 47 of Set 9 | malakal
# Processing Record 48 of Set 9 | mumford
# Processing Record 49 of Set 9 | vermillion
# Processing Record 50 of Set 9 | baykit
# Processing Record 1 of Set 10 | surt
# Processing Record 2 of Set 10 | hualmay
# Processing Record 3 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 4 of Set 10 | arman
# Processing Record 5 of Set 10 | kijini
# Processing Record 6 of Set 10 | raudeberg
# Processing Record 7 of Set 10 | burica
# City not found. Skipping...
# Processing Record 8 of Set 10 | takoradi
# Processing Record 9 of Set 10 | torbay
# Processing Record 10 of Set 10 | kodinsk
# Processing Record 11 of Set 10 | tilichiki
# Processing Record 12 of Set 10 | turan
# Processing Record 13 of Set 10 | roebourne
# Processing Record 14 of Set 10 | bac lieu
# Processing Record 15 of Set 10 | soledade
# Processing Record 16 of Set 10 | weinan
# Processing Record 17 of Set 10 | bartica
# Processing Record 18 of Set 10 | emmett
# Processing Record 19 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 20 of Set 10 | emerald
# Processing Record 21 of Set 10 | alyangula
# Processing Record 22 of Set 10 | haines junction
# Processing Record 23 of Set 10 | gaspe
# Processing Record 24 of Set 10 | suffolk
# Processing Record 25 of Set 10 | havre-saint-pierre
# Processing Record 26 of Set 10 | tromso
# Processing Record 27 of Set 10 | gushikawa
# Processing Record 28 of Set 10 | ahumada
# City not found. Skipping...
# Processing Record 29 of Set 10 | sangar
# Processing Record 30 of Set 10 | cambrai
# Processing Record 31 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 32 of Set 10 | caravelas
# Processing Record 33 of Set 10 | hami
# Processing Record 34 of Set 10 | tyret pervaya
# Processing Record 35 of Set 10 | norrtalje
# Processing Record 36 of Set 10 | mao
# Processing Record 37 of Set 10 | bhimunipatnam
# Processing Record 38 of Set 10 | kabare
# Processing Record 39 of Set 10 | tchollire
# Processing Record 40 of Set 10 | la venta del astillero
# Processing Record 41 of Set 10 | seoul
# Processing Record 42 of Set 10 | padang
# Processing Record 43 of Set 10 | florianopolis
# Processing Record 44 of Set 10 | birao
# Processing Record 45 of Set 10 | whyalla
# Processing Record 46 of Set 10 | cap-aux-meules
# Processing Record 47 of Set 10 | roanoke rapids
# Processing Record 48 of Set 10 | manggar
# Processing Record 49 of Set 10 | olavarria
# Processing Record 50 of Set 10 | dingle
# Processing Record 1 of Set 11 | san nicolas
# Processing Record 2 of Set 11 | olafsvik
# Processing Record 3 of Set 11 | peabiru
# Processing Record 4 of Set 11 | bonthe
# Processing Record 5 of Set 11 | otradnoye
# Processing Record 6 of Set 11 | ouesso
# Processing Record 7 of Set 11 | najran
# Processing Record 8 of Set 11 | sangod
# Processing Record 9 of Set 11 | pedernales
# Processing Record 10 of Set 11 | neustadt
# Processing Record 11 of Set 11 | yirol
# City not found. Skipping...
# Processing Record 12 of Set 11 | yakeshi
# Processing Record 13 of Set 11 | toulepleu
# City not found. Skipping...
# Processing Record 14 of Set 11 | otane
# Processing Record 15 of Set 11 | esso
# Processing Record 16 of Set 11 | camacha
# Processing Record 17 of Set 11 | putina
# Processing Record 18 of Set 11 | bilma
# Processing Record 19 of Set 11 | shubarkuduk
# Processing Record 20 of Set 11 | pozo colorado
# Processing Record 21 of Set 11 | vysha
# Processing Record 22 of Set 11 | stromness
# Processing Record 23 of Set 11 | linxia
# Processing Record 24 of Set 11 | richards bay
# Processing Record 25 of Set 11 | pontes e lacerda
# Processing Record 26 of Set 11 | borujerd
# Processing Record 27 of Set 11 | deputatskiy
# Processing Record 28 of Set 11 | tuatapere
# Processing Record 29 of Set 11 | tynda
# Processing Record 30 of Set 11 | rio grande
# Processing Record 31 of Set 11 | nizhniy kuranakh
# Processing Record 32 of Set 11 | zlynka
# Processing Record 33 of Set 11 | coos bay
# Processing Record 34 of Set 11 | cornwall
# Processing Record 35 of Set 11 | mus
# Processing Record 36 of Set 11 | pontianak
# Processing Record 37 of Set 11 | onega
# Processing Record 38 of Set 11 | ha tinh
# Processing Record 39 of Set 11 | sataua
# City not found. Skipping...
# Processing Record 40 of Set 11 | qaqortoq
# Processing Record 41 of Set 11 | diu
# Processing Record 42 of Set 11 | jelgava
# Processing Record 43 of Set 11 | karwar
# Processing Record 44 of Set 11 | ballina
# Processing Record 45 of Set 11 | gunjur
# Processing Record 46 of Set 11 | poshekhonye
# Processing Record 47 of Set 11 | hervey bay
# Processing Record 48 of Set 11 | jinxiang
# Processing Record 49 of Set 11 | sao felix do xingu
# Processing Record 50 of Set 11 | sinnamary
# Processing Record 1 of Set 12 | bairiki
# Processing Record 2 of Set 12 | makakilo city
# Processing Record 3 of Set 12 | port-gentil
# Processing Record 4 of Set 12 | arcachon
# Processing Record 5 of Set 12 | lerum
# Processing Record 6 of Set 12 | zemio
# Processing Record 7 of Set 12 | norman wells
# Processing Record 8 of Set 12 | porto nacional
# Processing Record 9 of Set 12 | bokoro
# Processing Record 10 of Set 12 | mount gambier
# Processing Record 11 of Set 12 | mago
# Processing Record 12 of Set 12 | chipinge
# Processing Record 13 of Set 12 | hofn
# Processing Record 14 of Set 12 | voh
# Processing Record 15 of Set 12 | northam
# Processing Record 16 of Set 12 | heyang
# Processing Record 17 of Set 12 | izazi
# Processing Record 18 of Set 12 | tekeli
# Processing Record 19 of Set 12 | carutapera
# Processing Record 20 of Set 12 | araouane
# Processing Record 21 of Set 12 | yarke pole
# Processing Record 22 of Set 12 | coquimbo
# Processing Record 23 of Set 12 | georgiyevka
# Processing Record 24 of Set 12 | buriti bravo
# Processing Record 25 of Set 12 | nam tha
# City not found. Skipping...
# Processing Record 26 of Set 12 | carlyle
# Processing Record 27 of Set 12 | boa vista
# Processing Record 28 of Set 12 | doha
# Processing Record 29 of Set 12 | sahrak
# City not found. Skipping...
# Processing Record 30 of Set 12 | machachi
# Processing Record 31 of Set 12 | goderich
# Processing Record 32 of Set 12 | okhotsk
# Processing Record 33 of Set 12 | sekudai
# Processing Record 34 of Set 12 | kiruna
# Processing Record 35 of Set 12 | virginia beach
# Processing Record 36 of Set 12 | kismayo
# Processing Record 37 of Set 12 | gao
# Processing Record 38 of Set 12 | tomatlan
# Processing Record 39 of Set 12 | shahganj
# Processing Record 40 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 41 of Set 12 | pangody
# Processing Record 42 of Set 12 | upice
# Processing Record 43 of Set 12 | arkhangelos
# City not found. Skipping...
# Processing Record 44 of Set 12 | lichinga
# Processing Record 45 of Set 12 | saint-ambroise
# Processing Record 46 of Set 12 | barretos
# Processing Record 47 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 48 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 12 | ajdabiya
# Processing Record 50 of Set 12 | camabatela
# Processing Record 1 of Set 13 | rojhan
# Processing Record 2 of Set 13 | talcahuano
# Processing Record 3 of Set 13 | bowen
# Processing Record 4 of Set 13 | vila
# Processing Record 5 of Set 13 | arawa
# Processing Record 6 of Set 13 | paratinga
# Processing Record 7 of Set 13 | banff
# Processing Record 8 of Set 13 | ayia marina
# Processing Record 9 of Set 13 | taoudenni
# Processing Record 10 of Set 13 | tual
# Processing Record 11 of Set 13 | zhezkazgan
# Processing Record 12 of Set 13 | gondanglegi
# Processing Record 13 of Set 13 | sorong
# Processing Record 14 of Set 13 | sarukhan
# Processing Record 15 of Set 13 | maniitsoq
# Processing Record 16 of Set 13 | kristiansund
# Processing Record 17 of Set 13 | vawkavysk
# Processing Record 18 of Set 13 | yarmouth
# Processing Record 19 of Set 13 | stoyba
# City not found. Skipping...
# Processing Record 20 of Set 13 | ponta delgada
# Processing Record 21 of Set 13 | milkovo
# Processing Record 22 of Set 13 | rodrigues alves
# Processing Record 23 of Set 13 | yeroham
# Processing Record 24 of Set 13 | prince rupert
# Processing Record 25 of Set 13 | stykkisholmur
# Processing Record 26 of Set 13 | elko
# Processing Record 27 of Set 13 | sao jose da coroa grande
# Processing Record 28 of Set 13 | kushmurun
# Processing Record 29 of Set 13 | dharur
# Processing Record 30 of Set 13 | datong
# Processing Record 31 of Set 13 | guia lopes da laguna
# Processing Record 32 of Set 13 | vila velha
# Processing Record 33 of Set 13 | pitea
# Processing Record 34 of Set 13 | watertown
# Processing Record 35 of Set 13 | buala
# Processing Record 36 of Set 13 | gurskoye
# City not found. Skipping...
# Processing Record 37 of Set 13 | mackenzie
# Processing Record 38 of Set 13 | hellvik
# Processing Record 39 of Set 13 | khorixas
# Processing Record 40 of Set 13 | mahon
# Processing Record 41 of Set 13 | clinton
# Processing Record 42 of Set 13 | puerto santander
# Processing Record 43 of Set 13 | umba
# Processing Record 44 of Set 13 | smithers
# Processing Record 45 of Set 13 | liwale
# Processing Record 46 of Set 13 | santo angelo
# Processing Record 47 of Set 13 | rosarito
# Processing Record 48 of Set 13 | chateaubelair
# Processing Record 49 of Set 13 | cap malheureux
# Processing Record 50 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 1 of Set 14 | lagoa
# Processing Record 2 of Set 14 | taiyuan
# Processing Record 3 of Set 14 | vrbove
# Processing Record 4 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 5 of Set 14 | willowmore
# Processing Record 6 of Set 14 | mezen
# Processing Record 7 of Set 14 | skjervoy
# Processing Record 8 of Set 14 | marienburg
# Processing Record 9 of Set 14 | santa cruz
# Processing Record 10 of Set 14 | contamana
# Processing Record 11 of Set 14 | batsfjord
# Processing Record 12 of Set 14 | altay
# Processing Record 13 of Set 14 | aripuana
# Processing Record 14 of Set 14 | kutum
# Processing Record 15 of Set 14 | paciran
# Processing Record 16 of Set 14 | ust-ilimsk
# Processing Record 17 of Set 14 | mayor pablo lagerenza
# Processing Record 18 of Set 14 | coahuayana
# Processing Record 19 of Set 14 | kupang
# Processing Record 20 of Set 14 | san jose
# Processing Record 21 of Set 14 | dauphin
# Processing Record 22 of Set 14 | kaduna
# Processing Record 23 of Set 14 | north bend
# Processing Record 24 of Set 14 | carndonagh
# Processing Record 25 of Set 14 | bako
# Processing Record 26 of Set 14 | bokspits
# City not found. Skipping...
# Processing Record 27 of Set 14 | donegal
# Processing Record 28 of Set 14 | playa vicente
# Processing Record 29 of Set 14 | nantucket
# Processing Record 30 of Set 14 | wilmington
# Processing Record 31 of Set 14 | karangampel
# Processing Record 32 of Set 14 | lakatoro
# Processing Record 33 of Set 14 | locri
# Processing Record 34 of Set 14 | kasongo-lunda
# Processing Record 35 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 36 of Set 14 | yebaishou
# Processing Record 37 of Set 14 | severnyy
# Processing Record 38 of Set 14 | pau dos ferros
# Processing Record 39 of Set 14 | dwarka
# Processing Record 40 of Set 14 | palmer
# Processing Record 41 of Set 14 | gamba
# Processing Record 42 of Set 14 | qianguo
# Processing Record 43 of Set 14 | martapura
# Processing Record 44 of Set 14 | biak
# Processing Record 45 of Set 14 | kangaatsiaq
# Processing Record 46 of Set 14 | andi
# Processing Record 47 of Set 14 | puerto del rosario
# Processing Record 48 of Set 14 | bluefields
# Processing Record 49 of Set 14 | evinayong
# Processing Record 50 of Set 14 | santa fe
# Processing Record 1 of Set 15 | bhag
# Processing Record 2 of Set 15 | eureka
# Processing Record 3 of Set 15 | san cristobal
# Processing Record 4 of Set 15 | tiarei
# Processing Record 5 of Set 15 | marawi
# Processing Record 6 of Set 15 | tsentralnyy
# City not found. Skipping...
# Processing Record 7 of Set 15 | honningsvag
# Processing Record 8 of Set 15 | carrickfergus
# Processing Record 9 of Set 15 | slavgorodskoye
# Processing Record 10 of Set 15 | wanning
# Processing Record 11 of Set 15 | piranhas
# Processing Record 12 of Set 15 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 15 | benguela
# Processing Record 14 of Set 15 | balsas
# Processing Record 15 of Set 15 | avera
# Processing Record 16 of Set 15 | college park
# Processing Record 17 of Set 15 | myaundzha
# Processing Record 18 of Set 15 | alexandria
# Processing Record 19 of Set 15 | tabou
# Processing Record 20 of Set 15 | kemin
# Processing Record 21 of Set 15 | ambon
# Processing Record 22 of Set 15 | bongandanga
# Processing Record 23 of Set 15 | cumra
# Processing Record 24 of Set 15 | tabialan
# City not found. Skipping...
# Processing Record 25 of Set 15 | antofagasta
# Processing Record 26 of Set 15 | conakry
# Processing Record 27 of Set 15 | maragogi
# Processing Record 28 of Set 15 | wonthaggi
# Processing Record 29 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 30 of Set 15 | wamba
# Processing Record 31 of Set 15 | astipalaia
# City not found. Skipping...
# Processing Record 32 of Set 15 | bereda
# Processing Record 33 of Set 15 | tarauaca
# Processing Record 34 of Set 15 | westport
# Processing Record 35 of Set 15 | honiara
# Processing Record 36 of Set 15 | aksu
# Processing Record 37 of Set 15 | praia
# Processing Record 38 of Set 15 | maningrida
# Processing Record 39 of Set 15 | zhanaozen
# Processing Record 40 of Set 15 | mocuba
# Processing Record 41 of Set 15 | bull savanna
# Processing Record 42 of Set 15 | gizo
# Processing Record 43 of Set 15 | korla
# Processing Record 44 of Set 15 | oranjestad
# Processing Record 45 of Set 15 | edd
# Processing Record 46 of Set 15 | kasempa
# Processing Record 47 of Set 15 | lakes entrance
# Processing Record 48 of Set 15 | portobelo
# Processing Record 49 of Set 15 | tessalit
# Processing Record 50 of Set 15 | monroe
# Processing Record 1 of Set 16 | mbala
# Processing Record 2 of Set 16 | strezhevoy
# Processing Record 3 of Set 16 | sept-iles
# Processing Record 4 of Set 16 | hyeres
# Processing Record 5 of Set 16 | lucapa
# Processing Record 6 of Set 16 | meulaboh
# Processing Record 7 of Set 16 | neuquen
# Processing Record 8 of Set 16 | shieli
# Processing Record 9 of Set 16 | tinskoy
# Processing Record 10 of Set 16 | brahmapuri
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 694

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Upernavik      GL  72.7868  -56.1549     47.19        66           0
# 1        Rikitea      PF -23.1203 -134.9692     68.00        75         100
# 2      Borgarnes      IS  64.5383  -21.9206     58.80        60         100
# 3  Saint Anthony      US  45.0205  -93.2180     86.95        63          20
# 4       Cidreira      BR -30.1811  -50.2056     62.94        95         100
# 5    Yellowknife      CA  62.4560 -114.3525     57.56        76          53
# 6      Jamestown      US  42.0970  -79.2353     80.06        38         100
# 7            Vao      NC -22.6667  167.4833     69.44        53          97
# 8     Nikolskoye      RU  59.7035   30.7861     64.29        89          73
# 9         Atuona      PF  -9.8000 -139.0333     76.66        74          12
#
#    Wind Speed Current Description
# 0        5.53           clear sky
# 1        4.88          light rain
# 2        5.39     overcast clouds
# 3        8.05          few clouds
# 4        4.70       moderate rain
# 5        4.00       broken clouds
# 6        8.05     overcast clouds
# 7       20.24     overcast clouds
# 8        4.83       broken clouds
# 9       12.77          few clouds

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [44], in <cell line: 6>()
#       3 output_data_file = "Weather_Database/WeatherPy_Database.csv"
#       5 # Export the City_Data into a CSV.
# ----> 6 city_data_df.to_csv(output_data_file, index_label="City_ID")
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:3551, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3540 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3542 formatter = DataFrameFormatter(
#    3543     frame=df,
#    3544     header=header,
#    (...)
#    3548     decimal=decimal,
#    3549 )
# -> 3551 return DataFrameRenderer(formatter).to_csv(
#    3552     path_or_buf,
#    3553     line_terminator=line_terminator,
#    3554     sep=sep,
#    3555     encoding=encoding,
#    3556     errors=errors,
#    3557     compression=compression,
#    3558     quoting=quoting,
#    3559     columns=columns,
#    3560     index_label=index_label,
#    3561     mode=mode,
#    3562     chunksize=chunksize,
#    3563     quotechar=quotechar,
#    3564     date_format=date_format,
#    3565     doublequote=doublequote,
#    3566     escapechar=escapechar,
#    3567     storage_options=storage_options,
#    3568 )
#
# File ~\anaconda3\lib\site-packages\pandas\io\formats\format.py:1180, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1159     created_buffer = False
#    1161 csv_formatter = CSVFormatter(
#    1162     path_or_buf=path_or_buf,
#    1163     line_terminator=line_terminator,
#    (...)
#    1178     formatter=self.fmt,
#    1179 )
# -> 1180 csv_formatter.save()
#    1182 if created_buffer:
#    1183     assert isinstance(path_or_buf, StringIO)
#
# File ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py:241, in CSVFormatter.save(self)
#     237 """
#     238 Create the writer & save.
#     239 """
#     240 # apply compression and byte/text conversion
# --> 241 with get_handle(
#     242     self.filepath_or_buffer,
#     243     self.mode,
#     244     encoding=self.encoding,
#     245     errors=self.errors,
#     246     compression=self.compression,
#     247     storage_options=self.storage_options,
#     248 ) as handles:
#     249
#     250     # Note: self.encoding is irrelevant here
#     251     self.writer = csvlib.writer(
#     252         handles.handle,
#     253         lineterminator=self.line_terminator,
#    (...)
#     258         quotechar=self.quotechar,
#     259     )
#     261     self._save()
#
# File ~\anaconda3\lib\site-packages\pandas\io\common.py:697, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     695 # Only for write methods
#     696 if "r" not in mode and is_path:
# --> 697     check_parent_directory(str(handle))
#     699 if compression:
#     700     if compression != "zstd":
#     701         # compression libraries do not like an explicit text-mode
#
# File ~\anaconda3\lib\site-packages\pandas\io\common.py:571, in check_parent_directory(path)
#     569 parent = Path(path).parent
#     570 if not parent.is_dir():
# --> 571     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'Weather_Database'
